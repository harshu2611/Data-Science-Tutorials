# %% [markdown]
# # GIT

# %% [markdown]
# ls -->  check all the file in your current folder <br>
# pwd --> check your current working directory <br>
# clear --> clear the terminal<br>

# %% [markdown]
# git --> check if git is working or not<br>
# git init --> use to initialize the git<br>
# git add . --> add all the files for tracking<br>
# git commit -m "any message"<br>
#     - if have any error:-<br>
#         git config --global user.email "you@example.com"
#         git config --global user.name "your username"<br>
# git branch -->
