# %% [markdown]
# # HEADING

# %% [markdown]
# # H1
# ## H2
# ### H3
# #### H4
# ##### H5
# ###### H6

# %% [markdown]
# # paragraph

# %% [markdown]
# THIS IS A PARAGRAPH <BR>
# THIS IS SECOND LINE

# %% [markdown]
# # Text Formatting

# %% [markdown]
# This is in **bold** <br>
# This is in *italics*<br>
# This is in ~~Deleted~~

# %% [markdown]
# # horizontal rule

# %% [markdown]
# section 1
#
# ---
#
# section 2

# %% [markdown]
# # blockquote

# %% [markdown]
# > this is block quote

# %% [markdown]
# # code

# %% [markdown]
# ``` python
# def hello(a)
#     print("hello world")
#
# ```

# %% [markdown]
# # lists

# %% [markdown]
# - python
#     - numpy
#     - pandas
# - sql
# - java
#
#
# 1. python
# 2. java
# 3. c++

# %% [markdown]
# # images

# %% [markdown]
# ! [image_name] (link of image)

# %% [markdown]
# # link

# %% [markdown]
# [Click to Register](link here)

# %% [markdown]
# # tables

# %% [markdown]
# | Name      | Branch        | Marks         |
# |-----------|---------------|---------------|
# | Harsh     | CSE           | 7             |
# | Viraj     | ECE           | 7             |
# | Krish     | IT            | 8             |

# %% [markdown]
# # Virtual Environment

# %% [markdown]
# - Step 1:

# %% [markdown]
# conda create -p venv python==3.13

# %% [markdown]
# -p --> venv created in within the same workspace <br>
# -n --> venv created in same location of conda<br>
#
#
# venv is just a environment name

# %% [markdown]
# - Step 2:

# %% [markdown]
# type y (ask to choose between y/n)

# %% [markdown]
# - Step 3:

# %% [markdown]
# conda activate venv/

# %% [markdown]
# - Step 4:

# %% [markdown]
# create file with name as requirement.txt outside the venv file <br>
#
# In requirement.txt we name the libraries and packages we want in particular projects.
# <br>
#
# pip install -r requirement.txt (this will install all packages and libraries we name in requirement.txt)

# %% [markdown]
# - Step 5:

# %% [markdown]
# Now we can start coding with .py files but for .ipynb file we need to install ipykernels

# %% [markdown]
# - Step 6:

# %% [markdown]
# open the terminal<br>
# check whethwer you are in venv environment or not (if not then activate it)<br>
# pip install ipykernel<br>

# %% [markdown]
# - Step 7:

# %% [markdown]
# for .py files always check whether you are in right virtual environment or not,<br>
# if yes then write python filename.py <br>
# if not then write cd filename then write python filename.py
